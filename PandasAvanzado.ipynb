# %% [markdown]
# #Trabajando con datos

# %%
import pandas as pd

# %%
dataset = pd.read_csv('alquiler.csv', sep = ';')

# %%
dataset
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# ...

# %%
#Genera un conjunto de estadísticas descriptivas de las columnas seleccionadas de un DataFrame.
dataset.describe()
# Out:
#             Cuartos      Vacantes        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#        Mantenimiento      Impuesto
# count   2.886700e+04  2.272300e+04
# mean    2.388062e+03  2.364410e+03
# std     3.918496e+04  1.795641e+05
# min     1.000000e+00  1.000000e+00
# 25%     5.900000e+02  1.100000e+02
# 50%     9.900000e+02  2.500000e+02
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           32960 non-null  object
#  1   Distrito       32960 non-null  object
#  2   Cuartos        32960 non-null  int64
#  3   Vacantes       32960 non-null  int64
#  4   Suites         32960 non-null  int64
#  5   Area           32960 non-null  int64
#  6   Valor          32943 non-null  float64
#  7   Mantenimiento  28867 non-null  float64
#  8   Impuesto       22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dataset.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# ...

# %% [markdown]
# ## Informaciones generales sobre la base de datos

# %%
dataset.dtypes
# Out:
# Tipo              object
# Distrito          object
# Cuartos            int64
# Vacantes           int64
# Suites             int64
# Area               int64
# Valor            float64
# Mantenimiento    float64
# Impuesto         float64
# dtype: object

# %%
tipos_de_datos = pd.DataFrame(dataset.dtypes, columns = ['Tipos de datos'])

# %%
tipos_de_datos.columns.name = 'Variables'

# %%
tipos_de_datos
# Out:
# Variables     Tipos de datos
# Tipo                  object
# Distrito              object
# Cuartos                int64
# Vacantes               int64
# Suites                 int64
# Area                   int64
# Valor                float64
# Mantenimiento        float64
# Impuesto             float64

# %%
dataset.shape
# Out:
# (32960, 9)

# %%
dataset.shape[0]
# Out:
# 32960

# %%
dataset.shape[1]
# Out:
# 9

# %%
print('La base de datos presenta {} registros (inmuebles) y {} variables'.format(dataset.shape[0], dataset.shape[1]))
# Out:
# La base de datos presenta 32960 registros (inmuebles) y 9 variables

# %% [markdown]
# ## Importando datos desde diferentes fuentes

# %%
json = open('datos/alquiler.json')
print(json.read())
# Out:
# [{"Tipo":"Habitación","Distrito":"San Borja","Cuartos":1,"Vacantes":0,"Suites":0,"Area":40,"Valor":1700.0,"Mantenimiento":500.0,"Impuesto":60.0},
# {"Tipo":"Casa","Distrito":"Lurigancho","Cuartos":2,"Vacantes":0,"Suites":1,"Area":100,"Valor":7000.0,"Mantenimiento":null,"Impuesto":null},
# {"Tipo":"Local comercial","Distrito":"Ate","Cuartos":0,"Vacantes":4,"Suites":0,"Area":150,"Valor":5200.0,"Mantenimiento":4020.0,"Impuesto":1111.0},
# {"Tipo":"Departamento","Distrito":"Pachacámac","Cuartos":1,"Vacantes":0,"Suites":0,"Area":15,"Valor":800.0,"Mantenimiento":390.0,"Impuesto":20.0},
# {"Tipo":"Departamento","Distrito":"Ate","Cuartos":1,"Vacantes":0,"Suites":0,"Area":48,"Valor":800.0,"Mantenimiento":230.0,"Impuesto":null},
# {"Tipo":"Departamento","Distrito":"Barranco","Cuartos":3,"Vacantes":1,"Suites":0,"Area":70,"Valor":1200.0,"Mantenimiento":null,"Impuesto":null},
# ...

# %%
#DataFrame de un archivo json
df_json = pd.read_json('datos/alquiler.json')
df_json
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %%
txt = open('datos/alquiler.txt')
print(txt.read())
# Out:
# Tipo	Distrito	Cuartos	Vacantes	Suites	Area	Valor	Mantenimiento	Impuesto
# Habitación	San Borja	1	0	0	40	1700	500	60
# Casa	Lurigancho	2	0	1	100	7000
# Local comercial	Ate	0	4	0	150	5200	4020	1111
# Departamento	Pachacámac	1	0	0	15	800	390	20
# Departamento	Ate	1	0	0	48	800	230
# Departamento	Barranco	3	1	0	70	1200
# Departamento	Comas	2	0	0	50	1300	301	17
# Casa en condominio	Ate	5	4	5	750	22000
# Casa en condominio	El Agustino	2	2	0	65	1000
# Local comercial	Pachacámac	0	3	0	695	35000	19193	3030

# %%
#DataFrame de un archivo txt
df_txt = pd.read_table('datos/alquiler.txt')
df_txt
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %%
#DataFrame de un archivo excel
df_xlsx = pd.read_excel('datos/alquiler.xlsx')
df_xlsx
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %%
#DataFrame de un archivo html
df_html = pd.read_html('datos/datos_html_1.html')
df_html
# Out:
# [     Año                           Campeón                        Subcampeón  \
#  0   2018                           Francia                           Croacia
#  1   2014                          Alemania                         Argentina
#  2   2010                            España                           Holanda
#  3   2006                            Italia                           Francia
#  4   2002                            Brasil                          Alemania
#  5   1998                           Francia                            Brasil
#  6   1994                            Brasil                            Italia
#  7   1990                          Alemania                         Argentina
#  8   1986                         Argentina                    Alemania (RFA)
#  9   1982                            Italia                    Alemania (RFA)
#  10  1978                         Argentina                           Holanda
# ...

# %%
df_html[0]
# Out:
#      Año                           Campeón                        Subcampeón  \
# 0   2018                           Francia                           Croacia
# 1   2014                          Alemania                         Argentina
# 2   2010                            España                           Holanda
# 3   2006                            Italia                           Francia
# 4   2002                            Brasil                          Alemania
# 5   1998                           Francia                            Brasil
# 6   1994                            Brasil                            Italia
# 7   1990                          Alemania                         Argentina
# 8   1986                         Argentina                    Alemania (RFA)
# 9   1982                            Italia                    Alemania (RFA)
# 10  1978                         Argentina                           Holanda
# ...

# %%
#Esta bien hecho, solo que la pagina dejó de funcionar
import requests
request = requests.get('https://www.federalreserve.gov/releases/h3/current/default.htm')
df_html = pd.read_html(request.text)
len(df_html)
# Out:
# 3

# %%
#Si quiero ver la primera tabla
df_html[0]
# Out:
#                   Date      Reserve balances required  \
#                   Date Reserve balance requirements 1
# 0              Month 7                        Month 7
# 1            Aug. 2019                         134639
# 2           Sept. 2019                         134707
# 3            Oct. 2019                         134998
# 4            Nov. 2019                         140705
# 5            Dec. 2019                         138984
# 6            Jan. 2020                         144816
# 7            Feb. 2020                         138370
# 8            Mar. 2020                         113139
# 9            Apr. 2020                              0
# 10            May 2020                              0
# 11           June 2020                              0
# 12           July 2020                              0
# 13           Aug. 2020                              0
# 14                 NaN                            NaN
# ...

# %%
#Si quiero ver la segunda tabla
df_html[1]
# Out:
#                   Date            Reserves                      \
#                   Date             Total 1            Required
# 0              Month 7             Month 7             Month 7
# 1            Aug. 2019             1586844              200608
# 2           Sept. 2019             1504805              199741
# 3            Oct. 2019             1547136              200621
# 4            Nov. 2019             1595222              206586
# 5            Dec. 2019             1698344              207239
# 6            Jan. 2020             1715219              214652
# 7            Feb. 2020             1726943              208324
# 8            Mar. 2020             2099369              167360
# 9            Apr. 2020             2953586                   0
# 10            May 2020             3217635                   0
# 11           June 2020             3043556                   0
# 12           July 2020             2718529                   0
# ...

# %% [markdown]
# # Series e Index

# %% [markdown]
# ## Eliminando valores repetidos

# %%
datos = pd.read_csv('alquiler.csv', sep = ';')

# %%
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# ...

# %%
datos['Tipo']
# Out:
# 0             Habitación
# 1                   Casa
# 2        Local comercial
# 3           Departamento
# 4           Departamento
#               ...
# 32955         Habitación
# 32956       Departamento
# 32957       Departamento
# 32958       Departamento
# 32959    Local comercial
# Name: Tipo, Length: 32960, dtype: object

# %%
#Al ser un DataFrame se puede buscar de la siguiente manera siempre que no tenga
#caracteres especiales o espacios
datos.Tipo
# Out:
# 0             Habitación
# 1                   Casa
# 2        Local comercial
# 3           Departamento
# 4           Departamento
#               ...
# 32955         Habitación
# 32956       Departamento
# 32957       Departamento
# 32958       Departamento
# 32959    Local comercial
# Name: Tipo, Length: 32960, dtype: object

# %%
tipos_de_inmueble = datos.Tipo

# %%
type(tipos_de_inmueble)
# Out:
# pandas.core.series.Series

# %%
#Eliminar duplicados para esta unica visualizacion, no actualiza el objeto
tipos_de_inmueble.drop_duplicates()
# Out:
# 0                        Habitación
# 1                              Casa
# 2                   Local comercial
# 3                      Departamento
# 7                Casa en condominio
# 16                Edificio completo
# 17                             Flat
# 29                     Tienda/Salón
# 80                          Almacén
# 83                   Casa comercial
# 117                   Casa de villa
# 159                         Terreno
# 207                         Cochera
# 347                            Loft
# 589      Tienda en Centro Comercial
# 2157                         Chacra
# 3354          Terreno em condominio
# 4379                        Oficina
# 4721                         Chalet
# 6983                         Studio
# 9687                          Hotel
# 23614              Local industrial
# Name: Tipo, dtype: object

# %%
tipos_de_inmueble
# Out:
# 0             Habitación
# 1                   Casa
# 2        Local comercial
# 3           Departamento
# 4           Departamento
#               ...
# 32955         Habitación
# 32956       Departamento
# 32957       Departamento
# 32958       Departamento
# 32959    Local comercial
# Name: Tipo, Length: 32960, dtype: object

# %%
#Eliminar duplicados y actualizar el objeto 'tipo_de_inmueble'
tipos_de_inmueble.drop_duplicates(inplace = True)

# %%
tipos_de_inmueble
# Out:
# 0                        Habitación
# 1                              Casa
# 2                   Local comercial
# 3                      Departamento
# 7                Casa en condominio
# 16                Edificio completo
# 17                             Flat
# 29                     Tienda/Salón
# 80                          Almacén
# 83                   Casa comercial
# 117                   Casa de villa
# 159                         Terreno
# 207                         Cochera
# 347                            Loft
# 589      Tienda en Centro Comercial
# 2157                         Chacra
# 3354          Terreno em condominio
# 4379                        Oficina
# 4721                         Chalet
# 6983                         Studio
# 9687                          Hotel
# 23614              Local industrial
# Name: Tipo, dtype: object

# %% [markdown]
# ## Redefiniendo el index

# %%
tipos_de_inmueble.index
# Out:
# Int64Index([    0,     1,     2,     3,     7,    16,    17,    29,    80,
#                83,   117,   159,   207,   347,   589,  2157,  3354,  4379,
#              4721,  6983,  9687, 23614],
#            dtype='int64')

# %%
type(tipos_de_inmueble)
# Out:
# pandas.core.series.Series

# %%
#Lo convierto a DataFrame para poder trabajarlo
tipos_de_inmueble = pd.DataFrame(tipos_de_inmueble)

# %%
type(tipos_de_inmueble)
# Out:
# pandas.core.frame.DataFrame

# %%
#Cant. de filas
tipos_de_inmueble.shape[0]
# Out:
# 22

# %%
#Para que los indices sean secuenciales
tipos_de_inmueble.index = range(tipos_de_inmueble.shape[0])
#Tambien se pudiera hacer: df.index = range(len(df))

# %%
tipos_de_inmueble.index
# Out:
# RangeIndex(start=0, stop=22, step=1)

# %%
tipos_de_inmueble
# Out:
#                           Tipo
# 0                   Habitación
# 1                         Casa
# 2              Local comercial
# 3                 Departamento
# 4           Casa en condominio
# 5            Edificio completo
# 6                         Flat
# 7                 Tienda/Salón
# 8                      Almacén
# 9               Casa comercial
# 10               Casa de villa
# 11                     Terreno
# 12                     Cochera
# 13                        Loft
# 14  Tienda en Centro Comercial
# 15                      Chacra
# 16       Terreno em condominio
# 17                     Oficina
# 18                      Chalet
# 19                      Studio
# 20                       Hotel
# 21            Local industrial

# %%
#Le agrego nombre a la primera columna
tipos_de_inmueble.columns.name = 'Id'

# %%
tipos_de_inmueble
# Out:
# Id                        Tipo
# 0                   Habitación
# 1                         Casa
# 2              Local comercial
# 3                 Departamento
# 4           Casa en condominio
# 5            Edificio completo
# 6                         Flat
# 7                 Tienda/Salón
# 8                      Almacén
# 9               Casa comercial
# 10               Casa de villa
# 11                     Terreno
# 12                     Cochera
# 13                        Loft
# 14  Tienda en Centro Comercial
# 15                      Chacra
# 16       Terreno em condominio
# 17                     Oficina
# 18                      Chalet
# 19                      Studio
# 20                       Hotel
# 21            Local industrial

# %% [markdown]
# ## Creando series

# %%
data = [1,2,3,4,5]

# %%
s = pd.Series(data)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
index = ['Linea' + str(i) for i in range(5)]
index
# Out:
# ['Linea0', 'Linea1', 'Linea2', 'Linea3', 'Linea4']

# %%
#Cambio el indice a la serie
s = pd.Series(data, index)
s
# Out:
# Linea0    1
# Linea1    2
# Linea2    3
# Linea3    4
# Linea4    5
# dtype: int64

# %%
data = {'Linea' + str(i) : i+1 for i in range(5)}
data
# Out:
# {'Linea0': 1, 'Linea1': 2, 'Linea2': 3, 'Linea3': 4, 'Linea4': 5}

# %%
s = pd.Series(data)
s
# Out:
# Linea0    1
# Linea1    2
# Linea2    3
# Linea3    4
# Linea4    5
# dtype: int64

# %%
s1 = s + 2
s1
# Out:
# Linea0    3
# Linea1    4
# Linea2    5
# Linea3    6
# Linea4    7
# dtype: int64

# %%
#Se puede realizar operaciones aritmeticas entre series, si las series tienen el mismo index
s2 = s1 + s
s2
# Out:
# Linea0     4
# Linea1     6
# Linea2     8
# Linea3    10
# Linea4    12
# dtype: int64

# %% [markdown]
# ## Creando DataFrames

# %%
datos = {'A': {'X': 1, 'Y': 3}, 'B': {'X': 2, 'Y': 4}}
df = pd.DataFrame(datos)
df
# Out:
#    A  B
# X  1  2
# Y  3  4

# %%
datos = [('A', 'B'), ('C', 'D')]
df = pd.DataFrame(datos, columns = ['L1', 'L2'],  index = ['C1', 'C2'])
df
# Out:
#    L1 L2
# C1  A  B
# C2  C  D

# %%
#Concatenando dataframes
df1 = pd.DataFrame({'A': {'X': 1}, 'B': {'X': 2}})
df2 = pd.DataFrame({'C': {'X': 3}, 'D': {'X': 4}})
pd.concat([df1, df2])
# Out:
#      A    B    C    D
# X  1.0  2.0  NaN  NaN
# X  NaN  NaN  3.0  4.0

# %%
datos = [[1, 2, 3], [4, 5, 6]]
index = 'X,Y'.split(',') #Crea una lista: ['X', 'Y']
columns = list('CBA')[::-1] # ['A', 'B', 'C']
df = pd.DataFrame(datos, index, columns)
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6

# %%
data = [[1,2,3],[4,5,6],[7,8,9]]
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
index = ['Linea' + str(i) for i in range(3)]
index
# Out:
# ['Linea0', 'Linea1', 'Linea2']

# %%
df1 = pd.DataFrame(data, index)
df1
# Out:
#         0  1  2
# Linea0  1  2  3
# Linea1  4  5  6
# Linea2  7  8  9

# %%
columns = ['Columna' + str(i) for i in range(3)]
columns
# Out:
# ['Columna0', 'Columna1', 'Columna2']

# %%
df1 = pd.DataFrame(data, index, columns)
df1
# Out:
#         Columna0  Columna1  Columna2
# Linea0         1         2         3
# Linea1         4         5         6
# Linea2         7         8         9

# %%
data = {'Columna0':{'Linea0':1, 'Linea1':4, 'Linea2':7}, 
        'Columna1':{'Linea0':2, 'Linea1':5, 'Linea2':8}, 
        'Columna2':{'Linea0':3, 'Linea1':6, 'Linea2':9}}
data
# Out:
# {'Columna0': {'Linea0': 1, 'Linea1': 4, 'Linea2': 7},
#  'Columna1': {'Linea0': 2, 'Linea1': 5, 'Linea2': 8},
#  'Columna2': {'Linea0': 3, 'Linea1': 6, 'Linea2': 9}}

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#         Columna0  Columna1  Columna2
# Linea0         1         2         3
# Linea1         4         5         6
# Linea2         7         8         9

# %%
data = [(1,2,3),(4,5,6),(7,8,9)]
data
# Out:
# [(1, 2, 3), (4, 5, 6), (7, 8, 9)]

# %%
df3 = pd.DataFrame(data,index,columns)
df3
# Out:
#         Columna0  Columna1  Columna2
# Linea0         1         2         3
# Linea1         4         5         6
# Linea2         7         8         9

# %%
df1[df1 > 0] = 'A'
df1
# Out:
#        Columna0 Columna1 Columna2
# Linea0        A        A        A
# Linea1        A        A        A
# Linea2        A        A        A

# %%
df2[df2 > 0] = 'B'
df2
# Out:
#        Columna0 Columna1 Columna2
# Linea0        B        B        B
# Linea1        B        B        B
# Linea2        B        B        B

# %%
df3[df3 > 0] = 'C'
df3
# Out:
#        Columna0 Columna1 Columna2
# Linea0        C        C        C
# Linea1        C        C        C
# Linea2        C        C        C

# %%
#Concatenar los 3 dataframes, las columnas se utilizan como llaves y las filas se colocan secuencialmente,
#es decir se concatena verticalmente
df4 = pd.concat([df1,df2,df3])
df4
# Out:
#        Columna0 Columna1 Columna2
# Linea0        A        A        A
# Linea1        A        A        A
# Linea2        A        A        A
# Linea0        B        B        B
# Linea1        B        B        B
# Linea2        B        B        B
# Linea0        C        C        C
# Linea1        C        C        C
# Linea2        C        C        C

# %%
#Concatenar horizontalmente, axis = 1 se refiera a las filas
df5 = pd.concat([df1,df2,df3], axis = 1)
df5
# Out:
#        Columna0 Columna1 Columna2 Columna0 Columna1 Columna2 Columna0  \
# Linea0        A        A        A        B        B        B        C
# Linea1        A        A        A        B        B        B        C
# Linea2        A        A        A        B        B        B        C
#
#        Columna1 Columna2
# Linea0        C        C
# Linea1        C        C
# Linea2        C        C

# %% [markdown]
# # Filtrando datos

# %% [markdown]
# ## Reporte de analisis de inmuebles residenciales

# %%
datos = pd.read_csv('alquiler.csv', sep = ';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# ...

# %%
list(datos['Tipo'].drop_duplicates())
# Out:
# ['Habitación',
#  'Casa',
#  'Local comercial',
#  'Departamento',
#  'Casa en condominio',
#  'Edificio completo',
#  'Flat',
#  'Tienda/Salón',
#  'Almacén',
#  'Casa comercial',
#  'Casa de villa',
#  'Terreno',
#  'Cochera',
#  'Loft',
#  'Tienda en Centro Comercial',
#  'Chacra',
#  'Terreno em condominio',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
residencial = ['Habitación',
 'Casa',
 'Departamento',
 'Casa en condominio',
 'Casa comercial',
 'Casa de villa']
residencial
# Out:
# ['Habitación',
#  'Casa',
#  'Departamento',
#  'Casa en condominio',
#  'Casa comercial',
#  'Casa de villa']

# %%
seleccion = datos['Tipo'].isin(residencial)
seleccion
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
datos_residencial = datos[seleccion]
datos_residencial
# Out:
#                Tipo     Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0        Habitación    San Borja        1         0       0    40  1700.0
# 1              Casa   Lurigancho        2         0       1   100  7000.0
# 3      Departamento   Pachacámac        1         0       0    15   800.0
# 4      Departamento          Ate        1         0       0    48   800.0
# 5      Departamento     Barranco        3         1       0    70  1200.0
# ...             ...          ...      ...       ...     ...   ...     ...
# 32953  Departamento  Santa Anita        2         0       0    70   900.0
# 32955    Habitación   Pachacámac        0         0       0    27   800.0
# 32956  Departamento        Lince        3         1       2    78  1800.0
# 32957  Departamento        Rímac        2         1       0    48  1400.0
# 32958  Departamento        Rímac        2         0       0    70  3000.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# ...

# %%
#Para verificar
list(datos_residencial['Tipo'].drop_duplicates())
# Out:
# ['Habitación',
#  'Casa',
#  'Departamento',
#  'Casa en condominio',
#  'Casa comercial',
#  'Casa de villa']

# %%
#Como los indices no estan secuenciales se hace lo siguiente
datos_residencial.index = range(len(datos_residencial))
datos_residencial
# Out:
#                Tipo     Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0        Habitación    San Borja        1         0       0    40  1700.0
# 1              Casa   Lurigancho        2         0       1   100  7000.0
# 2      Departamento   Pachacámac        1         0       0    15   800.0
# 3      Departamento          Ate        1         0       0    48   800.0
# 4      Departamento     Barranco        3         1       0    70  1200.0
# ...             ...          ...      ...       ...     ...   ...     ...
# 22840  Departamento  Santa Anita        2         0       0    70   900.0
# 22841    Habitación   Pachacámac        0         0       0    27   800.0
# 22842  Departamento        Lince        3         1       2    78  1800.0
# 22843  Departamento        Rímac        2         1       0    48  1400.0
# 22844  Departamento        Rímac        2         0       0    70  3000.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# ...

# %% [markdown]
# ## Exportando base de datos

# %%
datos_residencial.to_csv('alquiler_residencial.csv', sep = ';')
#Se exportó la columna index tambien

# %%
datos_residencial_2 = pd.read_csv('alquiler_residencial.csv', sep = ';')
datos_residencial_2
#La columna 'Unnamed:0' es el index
# Out:
#        Unnamed: 0          Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 0               0    Habitación    San Borja        1         0       0    40
# 1               1          Casa   Lurigancho        2         0       1   100
# 2               2  Departamento   Pachacámac        1         0       0    15
# 3               3  Departamento          Ate        1         0       0    48
# 4               4  Departamento     Barranco        3         1       0    70
# ...           ...           ...          ...      ...       ...     ...   ...
# 22840       22840  Departamento  Santa Anita        2         0       0    70
# 22841       22841    Habitación   Pachacámac        0         0       0    27
# 22842       22842  Departamento        Lince        3         1       2    78
# 22843       22843  Departamento        Rímac        2         1       0    48
# 22844       22844  Departamento        Rímac        2         0       0    70
#
# ...

# %%
#Para no exportar el index,,si no se borró el archivo se lo sobreescribe
datos_residencial.to_csv('alquiler_residencial.csv', sep = ';', index = False)

# %%
datos_residencial_2 = pd.read_csv('alquiler_residencial.csv', sep = ';')
datos_residencial_2
# Out:
#                Tipo     Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0        Habitación    San Borja        1         0       0    40  1700.0
# 1              Casa   Lurigancho        2         0       1   100  7000.0
# 2      Departamento   Pachacámac        1         0       0    15   800.0
# 3      Departamento          Ate        1         0       0    48   800.0
# 4      Departamento     Barranco        3         1       0    70  1200.0
# ...             ...          ...      ...       ...     ...   ...     ...
# 22840  Departamento  Santa Anita        2         0       0    70   900.0
# 22841    Habitación   Pachacámac        0         0       0    27   800.0
# 22842  Departamento        Lince        3         1       2    78  1800.0
# 22843  Departamento        Rímac        2         1       0    48  1400.0
# 22844  Departamento        Rímac        2         0       0    70  3000.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# ...

# %% [markdown]
# # Organizando dataframes

# %%
data = [[1,2,3],[4,5,6],[7,8,9]]
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
list('321')
# Out:
# ['3', '2', '1']

# %%
df = pd.DataFrame(data, list('321'), list('ZYX'))
df
# Out:
#    Z  Y  X
# 3  1  2  3
# 2  4  5  6
# 1  7  8  9

# %%
#Ordenar el index
df.sort_index(inplace = True)
df
# Out:
#    Z  Y  X
# 1  7  8  9
# 2  4  5  6
# 3  1  2  3

# %%
#Ordenar las columnas
df.sort_index(inplace = True, axis = 1)
df
# Out:
#    X  Y  Z
# 1  9  8  7
# 2  6  5  4
# 3  3  2  1

# %%
#Ordenar los valores por la columna x
df.sort_values(by = 'X', inplace = True)
df
#Los indices se vuelven a desordenar
# Out:
#    X  Y  Z
# 3  3  2  1
# 2  6  5  4
# 1  9  8  7

# %%
#Ordenar los valores horizontalmente
df.sort_values(by = '3', axis = 1, inplace = True)
df
# Out:
#    Z  Y  X
# 3  1  2  3
# 2  4  5  6
# 1  7  8  9

# %% [markdown]
# # Selecciones y Frecuencias

# %%
datos = pd.read_csv('alquiler_residencial.csv', sep = ';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento     Barranco        3         1       0    70   1200.0
# 5        Departamento        Comas        2         0       0    50   1300.0
# 6  Casa en condominio          Ate        5         4       5   750  22000.0
# 7  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 8        Departamento   Pachacámac        1         0       0    36   1200.0
# 9        Departamento      Mi Perú        2         1       0    70   1500.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2          390.0      20.0
# ...

# %%
#Seleccione solamente los inmuebles con tipo 'Departamento'
seleccion = datos['Tipo'] == 'Departamento'
n1 = datos[seleccion].shape[0] #Cant. o frecuencia de departamentos
n1
# Out:
# 19532

# %%
#Seleccione los inmuebles clasificados con tipos 'Casa', 'Casa en condominio' y 'Casa de villa'
seleccion = (datos['Tipo'] == 'Casa') | (datos['Tipo'] == 'Casa en condominio') |  (datos['Tipo'] == 'Casa de villa')
n2 = datos[seleccion].shape[0]
n2
# Out:
# 2212

# %%
#Seleccione los inmuebles con area entre 60 y 100 metros cuadrados, incluyendo los limites
seleccion = (datos['Area'] >= 60) & (datos['Area'] <= 100)
n3 = datos[seleccion].shape[0]
n3
# Out:
# 8736

# %%
#Seleccione los inmuebles que tengan por los menos 4 cuartos y alquiler menor a $2000.0
seleccion = (datos['Cuartos'] >= 4) & (datos['Valor'] < 2000.0)
n4 = datos[seleccion].shape[0]
n4
# Out:
# 41

# %%
print("N° de inmuebles clasificados con tipo 'Departamento' -> {}".format(n1))
print("N° de inmuebles clasificados con tipo 'Casa', 'Casa en codominio' y 'Casa de villa' -> {}".format(n2))
print("N° de inmuebles con area entre 60 y 100 metros cuadrados, incluyendo los limites -> {}".format(n3))
print("N° de inmuebles que tengan por lo menos 4 cuartos y alquiler menor que $2.000,0 -> {}".format(n4))
# Out:
# N° de inmuebles clasificados con tipo 'Departamento' -> 19532
# N° de inmuebles clasificados con tipo 'Casa', 'Casa en codominio' y 'Casa de villa' -> 2212
# N° de inmuebles con area entre 60 y 100 metros cuadrados, incluyendo los limites -> 8736
# N° de inmuebles que tengan por lo menos 4 cuartos y alquiler menor que $2.000,0 -> 41

# %% [markdown]
# # Formas de seleccion

# %%
'l1 l2 l3 l4'.split()
# Out:
# ['l1', 'l2', 'l3', 'l4']

# %%
data = [(1,2,3,4),
        (5,6,7,8),
        (8,10,11,12),
        (13,14,15,16)]
df = pd.DataFrame(data, 'l1 l2 l3 l4'.split(), 'c1 c2 c3 c4'.split())
df
# Out:
#     c1  c2  c3  c4
# l1   1   2   3   4
# l2   5   6   7   8
# l3   8  10  11  12
# l4  13  14  15  16

# %%
#Quiero ver los resultados de la columna 'c1'
df['c1']
# Out:
# l1     1
# l2     5
# l3     8
# l4    13
# Name: c1, dtype: int64

# %%
type(df['c1'])
# Out:
# pandas.core.series.Series

# %%
#Cuando selecciono más de una columna se deben poner dentro de una lista
df[['c3', 'c1']]
# Out:
#     c3  c1
# l1   3   1
# l2   7   5
# l3  11   8
# l4  15  13

# %%
type(df[['c3', 'c1']])
# Out:
# pandas.core.frame.DataFrame

# %%
#Quiero las filas l2 y l3, o sea posicion 1 y 2
df[1:3]
# Out:
#     c1  c2  c3  c4
# l2   5   6   7   8
# l3   8  10  11  12

# %%
#Quiero las filas desde l2 hasta al final y las columnas 'c3' y 'c1'
df[1:][['c3','c1']]
# Out:
#     c3  c1
# l2   7   5
# l3  11   8
# l4  15  13

# %%
#Metodo de Pandas: loc, utiliza los nombres de las columnas o filas, no los indices
#Quiero los valores de la linea l3
df.loc['l3']
# Out:
# c1     8
# c2    10
# c3    11
# c4    12
# Name: l3, dtype: int64

# %%
#Quiero los valores de las lineas l3 y l2
df.loc[['l3', 'l2']]
# Out:
#     c1  c2  c3  c4
# l3   8  10  11  12
# l2   5   6   7   8

# %%
#Quiero la interseccion de la fila l1 con la columna c2
df.loc['l1','c2']
# Out:
# 2

# %%
#Metodo de Pandas: iloc, utiliza las posiciones de las columnas o filas, no los nombres
#Quiero la interseccion de la fila l1 con la columna c2
df.iloc[0,1]
# Out:
# 2

# %%
#Quiero una matriz con las filas y columnas indicadas utilizando el metodo loc
df.loc[['l3','l1'],['c4','c1']]
# Out:
#     c4  c1
# l3  12   8
# l1   4   1

# %%
#Quiero una matriz con las filas y columnas indicadas utilizando el metodo iloc
df.iloc[[2,0],[3,0]]
# Out:
#     c4  c1
# l3  12   8
# l1   4   1

# %% [markdown]
# # Tratamiento de datos faltantes

# %%
datos = pd.read_csv('alquiler_residencial.csv', sep = ';')

# %%
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento     Barranco        3         1       0    70   1200.0
# 5        Departamento        Comas        2         0       0    50   1300.0
# 6  Casa en condominio          Ate        5         4       5   750  22000.0
# 7  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 8        Departamento   Pachacámac        1         0       0    36   1200.0
# 9        Departamento      Mi Perú        2         1       0    70   1500.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2          390.0      20.0
# ...

# %%
#Crea un dataframe donde si es true es porque tiene un valor null
datos.isnull()
# Out:
#         Tipo  Distrito  Cuartos  Vacantes  Suites   Area  Valor  \
# 0      False     False    False     False   False  False  False
# 1      False     False    False     False   False  False  False
# 2      False     False    False     False   False  False  False
# 3      False     False    False     False   False  False  False
# 4      False     False    False     False   False  False  False
# ...      ...       ...      ...       ...     ...    ...    ...
# 22840  False     False    False     False   False  False  False
# 22841  False     False    False     False   False  False  False
# 22842  False     False    False     False   False  False  False
# 22843  False     False    False     False   False  False  False
# 22844  False     False    False     False   False  False  False
#
#        Mantenimiento  Impuesto
# 0              False     False
# 1               True      True
# 2              False     False
# 3              False      True
# 4               True      True
# ...

# %%
#Funcion parecida a la anterior pero trabaja de manera contraria
datos.notnull()
# Out:
#        Tipo  Distrito  Cuartos  Vacantes  Suites  Area  Valor  Mantenimiento  \
# 0      True      True     True      True    True  True   True           True
# 1      True      True     True      True    True  True   True          False
# 2      True      True     True      True    True  True   True           True
# 3      True      True     True      True    True  True   True           True
# 4      True      True     True      True    True  True   True          False
# ...     ...       ...      ...       ...     ...   ...    ...            ...
# 22840  True      True     True      True    True  True   True           True
# 22841  True      True     True      True    True  True   True           True
# 22842  True      True     True      True    True  True   True           True
# 22843  True      True     True      True    True  True   True           True
# 22844  True      True     True      True    True  True   True           True
#
#        Impuesto
# 0          True
# ...

# %%
#Para saber exactamente que columnas tienen valores nulos se hace lo siguiente
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22845 entries, 0 to 22844
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           22845 non-null  object
#  1   Distrito       22845 non-null  object
#  2   Cuartos        22845 non-null  int64
#  3   Vacantes       22845 non-null  int64
#  4   Suites         22845 non-null  int64
#  5   Area           22845 non-null  int64
#  6   Valor          22836 non-null  float64
#  7   Mantenimiento  20796 non-null  float64
#  8   Impuesto       15976 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
#Como lo siguiente es una serie booleana, se puede convertir a condicion
datos['Valor'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22840    False
# 22841    False
# 22842    False
# 22843    False
# 22844    False
# Name: Valor, Length: 22845, dtype: bool

# %%
#Me trae solamente los valores en lo que la condicion es true
datos[datos['Valor'].isnull()]
# Out:
#               Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 58    Departamento          Ate        2         1       1    70    NaN
# 1515  Departamento  San Bartolo        2         0       0    75    NaN
# 1708          Casa        Lince        3         4       3   363    NaN
# 2039  Departamento   Chorrillos        2         0       0    95    NaN
# 2061  Departamento    San Borja        2         0       0    72    NaN
# 4998          Casa        Lince        3         2       1   100    NaN
# 8674  Departamento  San Bartolo        2         0       1    75    NaN
# 9061  Departamento     La Punta        3         0       1   135    NaN
# 9264  Departamento     La Perla        3         1       1   105    NaN
#
#       Mantenimiento  Impuesto
# 58            970.0      68.0
# 1515          878.0       NaN
# 1708            NaN       NaN
# 2039         1010.0     170.0
# 2061          850.0       NaN
# 4998            NaN       NaN
# ...

# %%
A = datos.shape[0] #Cant de lineas antes de la eliminacion
datos.dropna(subset = ['Valor'], inplace = True) #Elimina filas en la que la columna 'Valor' tenga valores NaN
B = datos.shape[0] #Cant de lineas despues de la eliminacion
A - B #Cant de lineas eliminadas
# Out:
# 9

# %%
#Ahora no hay valores nulos
datos[datos['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Distrito, Cuartos, Vacantes, Suites, Area, Valor, Mantenimiento, Impuesto]
# Index: []

# %% [markdown]
# ## Tratamiento condicional

# %%
#Podemos los valores nulos de la columna 'Mantenimiento' siempre y cuando el tipo sea 'Departamento'
datos[datos['Mantenimiento'].isnull()].shape[0] #Cant de lineas que tienen null en 'Mantenimiento'
# Out:
# 2047

# %%
seleccion = (datos['Mantenimiento'].isnull()) & (datos['Tipo'] == 'Departamento' )

# %%
A = datos.shape[0] #Cant de lineas antes de la eliminacion
datos = datos[~seleccion]
B = datos.shape[0] #Cant de lineas despues de la eliminacion
A - B #Cant de lineas eliminadas
# Out:
# 745

# %%
#Cant de lineas que todavia tienen null en 'Mantenimiento'
datos[datos['Mantenimiento'].isnull()].shape[0]
# Out:
# 1302

# %%
#Reemplazar los valores nulos restantes en 'Mantenimiento' e 'Impuesto' por 0
datos = datos.fillna({'Mantenimiento': 0, 'Impuesto': 0})

# %%
#Cant de lineas que todavia tienen null en 'Mantenimiento'
datos[datos['Mantenimiento'].isnull()].shape[0]
# Out:
# 0

# %%
#Cant de lineas que todavia tienen null en 'Impuesto'
datos[datos['Impuesto'].isnull()].shape[0]
# Out:
# 0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22091 entries, 0 to 22844
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           22091 non-null  object
#  1   Distrito       22091 non-null  object
#  2   Cuartos        22091 non-null  int64
#  3   Vacantes       22091 non-null  int64
#  4   Suites         22091 non-null  int64
#  5   Area           22091 non-null  int64
#  6   Valor          22091 non-null  float64
#  7   Mantenimiento  22091 non-null  float64
#  8   Impuesto       22091 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
#Exportar dataframe
datos.to_csv('alquiler_residencial.csv', sep = ';', index = False)

# %% [markdown]
# # Métodos de interpolación

# %%
#None es NaN
data = [0.5, None, None, 0.52, 0.54, None, None, 0.59, 0.6, None, 0.7]
s = pd.Series(data)
s
# Out:
# 0     0.50
# 1      NaN
# 2      NaN
# 3     0.52
# 4     0.54
# 5      NaN
# 6      NaN
# 7     0.59
# 8     0.60
# 9      NaN
# 10    0.70
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0     0.50
# 1     0.00
# 2     0.00
# 3     0.52
# 4     0.54
# 5     0.00
# 6     0.00
# 7     0.59
# 8     0.60
# 9     0.00
# 10    0.70
# dtype: float64

# %%
#Lo anterior es solo una visualizacion, para que se actualize hay que poner inplace = True
s
# Out:
# 0     0.50
# 1      NaN
# 2      NaN
# 3     0.52
# 4     0.54
# 5      NaN
# 6      NaN
# 7     0.59
# 8     0.60
# 9      NaN
# 10    0.70
# dtype: float64

# %%
#Sustituye NaN por un valor no nulo anterior a el
s.fillna(method = 'ffill')
# Out:
# 0     0.50
# 1     0.50
# 2     0.50
# 3     0.52
# 4     0.54
# 5     0.54
# 6     0.54
# 7     0.59
# 8     0.60
# 9     0.60
# 10    0.70
# dtype: float64

# %%
#Parecido al method 'ffil' pero comienza desde el final
s.fillna(method = 'bfill')
# Out:
# 0     0.50
# 1     0.52
# 2     0.52
# 3     0.52
# 4     0.54
# 5     0.59
# 6     0.59
# 7     0.59
# 8     0.60
# 9     0.70
# 10    0.70
# dtype: float64

# %%
#.mean() calcula la media de la serie
s.fillna(s.mean())
# Out:
# 0     0.500
# 1     0.575
# 2     0.575
# 3     0.520
# 4     0.540
# 5     0.575
# 6     0.575
# 7     0.590
# 8     0.600
# 9     0.575
# 10    0.700
# dtype: float64

# %%
#Para no reemplzar por ejemplo 5 veces seguidas NaN porque puede afectar los graficos, se usan los limites
s.fillna(method = 'ffill', limit = 1)
# Out:
# 0     0.50
# 1     0.50
# 2      NaN
# 3     0.52
# 4     0.54
# 5     0.54
# 6      NaN
# 7     0.59
# 8     0.60
# 9     0.60
# 10    0.70
# dtype: float64

# %%
#Para combinar dos metodos de fill
s1 = s.fillna(method = 'ffill', limit = 1)
s1
# Out:
# 0     0.50
# 1     0.50
# 2      NaN
# 3     0.52
# 4     0.54
# 5     0.54
# 6      NaN
# 7     0.59
# 8     0.60
# 9     0.60
# 10    0.70
# dtype: float64

# %%
s2 = s1.fillna(method = 'bfill', limit = 1)
s2
# Out:
# 0     0.50
# 1     0.50
# 2     0.52
# 3     0.52
# 4     0.54
# 5     0.54
# 6     0.59
# 7     0.59
# 8     0.60
# 9     0.60
# 10    0.70
# dtype: float64

# %% [markdown]
# # Nuevas variables

# %% [markdown]
# ## Creando nuevas variables

# %%
datos = pd.read_csv('alquiler_residencial.csv', sep = ';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            0.0       0.0
# 2          390.0      20.0
# ...

# %%
#Nueva columna
datos['Valor Bruto'] = (datos['Valor']) + (datos['Mantenimiento']) + (datos['Impuesto'])
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto  Valor Bruto
# 0          500.0      60.0       2260.0
# 1            0.0       0.0       7000.0
# ...

# %%
datos['Valor m2'] = (datos['Valor']) / (datos['Area'])
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto  Valor Bruto   Valor m2
# 0          500.0      60.0       2260.0  42.500000
# ...

# %%
#Redondear a dos decimales una columna
datos['Valor m2'] = datos['Valor m2'].round(2)
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto  Valor Bruto  Valor m2
# 0          500.0      60.0       2260.0     42.50
# ...

# %%
datos['Valor Bruto m2'] = ((datos['Valor']) / (datos['Area'])).round(2)
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto  Valor Bruto  Valor m2  Valor Bruto m2
# ...

# %%
#Agrupar tipos
casa = ['Casa', 'Casa en condominio', 'Casa de villa']
datos['Tipo Agrupado'] = datos['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Departamento')
datos
# Out:
#                Tipo     Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0        Habitación    San Borja        1         0       0    40  1700.0
# 1              Casa   Lurigancho        2         0       1   100  7000.0
# 2      Departamento   Pachacámac        1         0       0    15   800.0
# 3      Departamento          Ate        1         0       0    48   800.0
# 4      Departamento        Comas        2         0       0    50  1300.0
# ...             ...          ...      ...       ...     ...   ...     ...
# 22086  Departamento  Santa Anita        2         0       0    70   900.0
# 22087    Habitación   Pachacámac        0         0       0    27   800.0
# 22088  Departamento        Lince        3         1       2    78  1800.0
# 22089  Departamento        Rímac        2         1       0    48  1400.0
# 22090  Departamento        Rímac        2         0       0    70  3000.0
#
#        Mantenimiento  Impuesto  Valor Bruto  Valor m2  Valor Bruto m2  \
# ...

# %% [markdown]
# ## Excluyendo variables

# %%
datos_aux = pd.DataFrame(datos[['Tipo Agrupado','Valor m2','Valor Bruto','Valor Bruto m2']])
datos_aux.head(10)
# Out:
#   Tipo Agrupado  Valor m2  Valor Bruto  Valor Bruto m2
# 0  Departamento     42.50       2260.0           42.50
# 1          Casa     70.00       7000.0           70.00
# 2  Departamento     53.33       1210.0           53.33
# 3  Departamento     16.67       1030.0           16.67
# 4  Departamento     26.00       1618.0           26.00
# 5          Casa     29.33      22000.0           29.33
# 6          Casa     15.38       1000.0           15.38
# 7  Departamento     21.43       2216.0           21.43
# 8  Departamento     16.67       1969.0           16.67
# 9  Departamento     50.00       2611.0           50.00

# %%
#Borrar una columna
del datos_aux['Valor Bruto'] #Solo elimina una columna a la vez
datos_aux.head(10)
# Out:
#   Tipo Agrupado  Valor m2  Valor Bruto m2
# 0  Departamento     42.50           42.50
# 1          Casa     70.00           70.00
# 2  Departamento     53.33           53.33
# 3  Departamento     16.67           16.67
# 4  Departamento     26.00           26.00
# 5          Casa     29.33           29.33
# 6          Casa     15.38           15.38
# 7  Departamento     21.43           21.43
# 8  Departamento     16.67           16.67
# 9  Departamento     50.00           50.00

# %%
#Borrar una columna
datos_aux.pop('Valor Bruto m2') #Solo borra una columna a la vez
datos_aux.head(10)
# Out:
#   Tipo Agrupado  Valor m2
# 0  Departamento     42.50
# 1          Casa     70.00
# 2  Departamento     53.33
# 3  Departamento     16.67
# 4  Departamento     26.00
# 5          Casa     29.33
# 6          Casa     15.38
# 7  Departamento     21.43
# 8  Departamento     16.67
# 9  Departamento     50.00

# %%
#Borrar una columna
datos.drop(['Valor Bruto', 'Valor Bruto m2'], axis = 1, inplace = True) #Podemos excluir no sólo columnas (axis = 1), sino también líneas (default).
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 0          500.0      60.0     42.50  Departamento
# ...

# %%
datos.to_csv('alquiler_residencial.csv', sep = ';', index = False)

# %% [markdown]
# # Contadores

# %%
s = pd.Series(list('dfadsfasdfasdfdsafdsaa'))
s
# Out:
# 0     d
# 1     f
# 2     a
# 3     d
# 4     s
# 5     f
# 6     a
# 7     s
# 8     d
# 9     f
# 10    a
# 11    s
# 12    d
# 13    f
# 14    d
# 15    s
# 16    a
# 17    f
# 18    d
# 19    s
# 20    a
# 21    a
# dtype: object

# %%
s.unique()
# Out:
# array(['d', 'f', 'a', 's'], dtype=object)

# %%
s.value_counts()
# Out:
# d    6
# a    6
# f    5
# s    5
# dtype: int64

# %%
datos = pd.read_csv('alquiler.csv', sep = ';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# ...

# %%
#Valores unicos de una columna
datos.Tipo.unique()
# Out:
# array(['Habitación', 'Casa', 'Local comercial', 'Departamento',
#        'Casa en condominio', 'Edificio completo', 'Flat', 'Tienda/Salón',
#        'Almacén', 'Casa comercial', 'Casa de villa', 'Terreno', 'Cochera',
#        'Loft', 'Tienda en Centro Comercial', 'Chacra',
#        'Terreno em condominio', 'Oficina', 'Chalet', 'Studio', 'Hotel',
#        'Local industrial'], dtype=object)

# %%
datos.Tipo.value_counts()
# Out:
# Departamento                  19532
# Local comercial                6815
# Tienda/Salón                   1426
# Casa en condominio              996
# Casa                            967
# Habitación                      836
# Almacén                         623
# Flat                            476
# Edificio completo               301
# Casa comercial                  265
# Casa de villa                   249
# Tienda en Centro Comercial      247
# Cochera                          82
# Terreno                          70
# Loft                             51
# Oficina                          10
# Terreno em condominio             5
# Studio                            4
# Hotel                             2
# Chacra                            1
# Chalet                            1
# Local industrial                  1
# Name: Tipo, dtype: int64

# %% [markdown]
# # Estadisticas descriptivas

# %% [markdown]
# ## Creando agrupamientos

# %%
datos = pd.read_csv('alquiler_residencial.csv', sep = ';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 0          500.0      60.0     42.50  Departamento
# ...

# %%
#Media aritmetica
datos['Valor'].mean()
# Out:
# 5159.318636548821

# %%
#Ejemplo de una lista de barrios especificada, descomentar si se quiere probar
#barrios = ['Ate','Barranco','Comas','Lince','El Agustino','San Luis','Callao']
#seleccion = datos['Distrito'].isin(barrios)
#datos = datos[seleccion]
#datos.head(10)

# %%
#Para verificar la lista de barrios
datos['Distrito'].drop_duplicates()
# Out:
# 0                     San Borja
# 1                    Lurigancho
# 2                    Pachacámac
# 3                           Ate
# 4                         Comas
# 6                   El Agustino
# 7                       Mi Perú
# 12                     San Luis
# 13                       Callao
# 15                   San Miguel
# 17                   Santa Rosa
# 22                        Lince
# 23                   Chorrillos
# 26                  Jesús María
# 27                        Rímac
# 29                   Miraflores
# 36                        Breña
# 44                        Ancón
# 46                  Santa Anita
# 47      Villa María del Triunfo
# 57                Punta Hermosa
# 64                     La Perla
# 67       San Juan de Lurigancho
# 68                   Chaclacayo
# 79            Villa El Salvador
# 90                 Pueblo Libre
# 95                        Lurín
# 102                    La Punta
# 104                  Ventanilla
# ...

# %%
grupo_barrio = datos.groupby('Distrito')

# %%
type(grupo_barrio)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_barrio.groups
# Out:
# {'Ancón': [44, 1258, 1311, 1340, 1709, 1728, 2160, 2710, 2779, 3912, 3953, 4007, 4133, 4411, 4463, 4491, 4503, 4731, 4739, 5677, 5930, 5951, 6165, 6356, 6432, 6655, 7355, 7464, 7744, 7757, 7776, 7838, 7940, 8235, 8910, 9314, 9442, 9689, 9814, 10298, 10455, 10594, 10625, 10664, 10678, 10943, 11352, 11571, 11623, 11663, 11713, 11745, 12012, 12254, 12362, 12523, 12614, 13652, 13981, 14221, 14787, 14921, 15166, 15541, 15554, 15944, 16257, 16357, 16381, 17276, 17306, 17525, 17991, 18034, 18095, 18228, 18297, 18402, 18611, 18666, 18681, 18826, 18995, 19041, 19397, 19583, 20352, 20733, 20930, 21003, 21012, 21343, 21728], 'Ate': [3, 5, 14, 16, 21, 30, 32, 35, 42, 43, 61, 62, 63, 65, 69, 75, 80, 82, 94, 108, 111, 113, 118, 131, 133, 137, 152, 155, 157, 167, 168, 175, 188, 191, 210, 217, 224, 227, 236, 239, 242, 247, 262, 268, 277, 279, 294, 295, 296, 298, 305, 311, 314, 329, 339, 340, 349, 364, 370, 372, 378, 384, 391, 393, 404, 416, 436, 437, 439, 440, 443, 453, 456, 467, 468, 470, 478, 481,
# ...

# %%
#data es un dataframe
for barrio, data in grupo_barrio:
  print('{} -> {}'.format(barrio, data.Valor.mean()))
# Out:
# Ancón -> 3816.3440860215055
# Ate -> 6960.983080808081
# Barranco -> 1403.8297872340424
# Bellavista -> 972.5581395348837
# Breña -> 4099.119318181818
# Callao -> 4915.27950310559
# Carabayllo -> 1461.860465116279
# Carmen de La Legua -> 2523.6666666666665
# Chaclacayo -> 1428.0740740740741
# Chorrillos -> 8604.038684719535
# Cieneguilla -> 1044.642857142857
# Comas -> 8823.798661174047
# El Agustino -> 1152.6694915254238
# Independencia -> 909.2592592592592
# Jesús María -> 4001.75464037123
# La Molina -> 1425.2272727272727
# La Perla -> 5918.407407407408
# La Punta -> 2425.180751173709
# La Victoria -> 1141.7391304347825
# Lima -> 1310.0
# Lince -> 1736.1036931818182
# Los Olivos -> 1611.7272727272727
# Lurigancho -> 8852.132352941177
# Lurín -> 2327.7894736842104
# Magdalena del Mar -> 1886.5444444444445
# Mi Perú -> 1748.4660766961651
# Miraflores -> 5578.484848484848
# Pachacámac -> 1485.5675675675675
# Pucusana -> 5166.258992805755
# Pueblo Libre -> 8245.680555555555
# ...

# %%
grupo_barrio['Valor'].mean().round(2)
# Out:
# Distrito
# Ancón                      3816.34
# Ate                        6960.98
# Barranco                   1403.83
# Bellavista                  972.56
# Breña                      4099.12
# Callao                     4915.28
# Carabayllo                 1461.86
# Carmen de La Legua         2523.67
# Chaclacayo                 1428.07
# Chorrillos                 8604.04
# Cieneguilla                1044.64
# Comas                      8823.80
# El Agustino                1152.67
# Independencia               909.26
# Jesús María                4001.75
# La Molina                  1425.23
# La Perla                   5918.41
# La Punta                   2425.18
# La Victoria                1141.74
# Lima                       1310.00
# Lince                      1736.10
# Los Olivos                 1611.73
# Lurigancho                 8852.13
# Lurín                      2327.79
# Magdalena del Mar          1886.54
# Mi Perú                    1748.47
# ...

# %%
grupo_barrio[['Valor','Mantenimiento']].mean().round(2)
# Out:
#                            Valor  Mantenimiento
# Distrito
# Ancón                    3816.34         916.32
# Ate                      6960.98        3508.33
# Barranco                 1403.83         324.89
# Bellavista                972.56         170.33
# Breña                    4099.12         999.84
# Callao                   4915.28         674.36
# Carabayllo               1461.86         357.42
# Carmen de La Legua       2523.67         276.17
# Chaclacayo               1428.07         362.59
# Chorrillos               8604.04         857.22
# Cieneguilla              1044.64         163.39
# Comas                    8823.80        2076.44
# El Agustino              1152.67         179.83
# Independencia             909.26         135.22
# Jesús María              4001.75         922.65
# La Molina                1425.23         919.84
# La Perla                 5918.41        1077.08
# La Punta                 2425.18         557.34
# ...

# %% [markdown]
# ## Estadisticas descriptivas

# %%
grupo_barrio['Valor'].describe().round(2)
# Out:
#                           count     mean        std     min     25%     50%  \
# Distrito
# Ancón                      93.0  3816.34    5363.42   400.0   900.0  1700.0
# Ate                      3960.0  6960.98   11806.44   560.0  2500.0  4300.0
# Barranco                   47.0  1403.83    1496.62   450.0   800.0  1100.0
# Bellavista                 43.0   972.56     495.64   400.0   700.0   850.0
# Breña                     176.0  4099.12    3468.09   790.0  2400.0  3000.0
# Callao                    483.0  4915.28   44046.80   500.0  1200.0  1700.0
# Carabayllo                 43.0  1461.86    1033.67   480.0   900.0  1200.0
# Carmen de La Legua         30.0  2523.67    5820.90   485.0   525.0  1000.0
# Chaclacayo                135.0  1428.07     715.11   400.0  1000.0  1200.0
# Chorrillos               1034.0  8604.04  139880.67   400.0  2000.0  3000.0
# Cieneguilla                28.0  1044.64     467.27   450.0   742.5   900.0
# ...

# %%
#Extraer las estadisticas que queremos visualizar
grupo_barrio['Valor'].aggregate(['min','max']).rename(columns = {'min': 'Minimo','max': 'Maximo'})
# Out:
#                          Minimo     Maximo
# Distrito
# Ancón                     400.0    38000.0
# Ate                       560.0   600000.0
# Barranco                  450.0     8000.0
# Bellavista                400.0     3600.0
# Breña                     790.0    22000.0
# Callao                    500.0   800000.0
# Carabayllo                480.0     6000.0
# Carmen de La Legua        485.0    30000.0
# Chaclacayo                400.0     4500.0
# Chorrillos                400.0  4500000.0
# Cieneguilla               450.0     2300.0
# Comas                     400.0   100000.0
# El Agustino               500.0     5500.0
# Independencia             450.0     2000.0
# Jesús María               750.0  1250000.0
# La Molina                 610.0     6000.0
# La Perla                  400.0    30000.0
# La Punta                  400.0    55400.0
# La Victoria               650.0     2000.0
# Lima                      500.0     3500.0
# ...

# %%
#Activar la biblioteca y dejarla en linea para que pueda crear los graficos dentro de nuestro notebook
# %matplotlib inline
#Importar la biblioteca para que exista dentro del notebook
import matplotlib.pyplot as plt
#Crear un recurso
plt.rc('figure', figsize = (20,10))

# %%
#fig es donde va a ser guardado la figura
fig = grupo_barrio['Valor'].mean().plot.bar(color = 'blue')
fig.set_ylabel('Valor del Alquiler')
fig.set_title('Valor Medio del Alquiler por Distrito', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Medio del Alquiler por Distrito')

# %%
fig = grupo_barrio['Valor'].max().plot.bar(color = 'blue')
fig.set_ylabel('Valor del Alquiler')
fig.set_title('Valor Maximo del Alquiler por Distrito', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Maximo del Alquiler por Distrito')

# %% [markdown]
# # Creando rangos de valor

# %%
datos = pd.read_csv('alquiler.csv', sep = ';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# ...

# %%
#Agrupar los cuartos por:
#1 y 2
#3 y 4
#5 y 6
#7 o mas cuartos
clases = [0,2,4,6,100] #Se pone el limite, el ultimo como puede ser hasta infinito se puso un valor grande

# %%
cuartos = pd.cut(datos.Cuartos, clases)
cuartos #El cero es NaN porque no se considera para ninguna categoria
# Out:
# 0        (0.0, 2.0]
# 1        (0.0, 2.0]
# 2               NaN
# 3        (0.0, 2.0]
# 4        (0.0, 2.0]
#             ...
# 32955           NaN
# 32956    (2.0, 4.0]
# 32957    (0.0, 2.0]
# 32958    (0.0, 2.0]
# 32959           NaN
# Name: Cuartos, Length: 32960, dtype: category
# Categories (4, interval[int64, right]): [(0, 2] < (2, 4] < (4, 6] < (6, 100]]

# %%
#Frecuencias de cada una de las categorias
pd.value_counts(cuartos)
# Out:
# (0, 2]      12419
# (2, 4]       9894
# (4, 6]        709
# (6, 100]       87
# Name: Cuartos, dtype: int64

# %%
label = ['1 y 2 cuartos','3 y 4 cuartos','5 y 6 cuartos','7 cuartos o mas']

# %%
cuartos = pd.cut(datos.Cuartos, clases, labels = label)

# %%
pd.value_counts(cuartos)
# Out:
# 1 y 2 cuartos      12419
# 3 y 4 cuartos       9894
# 5 y 6 cuartos        709
# 7 cuartos o mas       87
# Name: Cuartos, dtype: int64

# %%
#Para incluir cero cuartos en la clasificacion
cuartos = pd.cut(datos.Cuartos, clases, labels = label, include_lowest = True)
pd.value_counts(cuartos)
# Out:
# 1 y 2 cuartos      22270
# 3 y 4 cuartos       9894
# 5 y 6 cuartos        709
# 7 cuartos o mas       87
# Name: Cuartos, dtype: int64

# %% [markdown]
# # Outliers

# %% [markdown]
# ## Incluyendo y excluyendo outliers

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (14,6))

# %%
datos = pd.read_csv('alquiler_residencial.csv', sep = ';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 0          500.0      60.0     42.50  Departamento
# ...

# %%
#La columna tiene que ser medible
datos.boxplot(['Valor']) #Es un grafico donde nos muestra la concentracion de los datos

# %%
#En el grafico anterior: le6 significa que es x10^6(millon), los valores por encima de 500.000 lo consideramos outliers
datos[datos['Valor'] >= 500000]
# Out:
#                      Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 7731         Departamento          Ate        1         1       0    65
# 10774  Casa en condominio       Callao        4         2       3   163
# 12822        Departamento       Callao        2         2       1   150
# 14023        Departamento  Jesús María        3         2       1   167
# 15715        Departamento   Chorrillos        4         1       1   300
#
#            Valor  Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 7731    600000.0          980.0     120.0   9230.77  Departamento
# 10774   800000.0          900.0       0.0   4907.98          Casa
# 12822   550000.0          850.0     150.0   3666.67  Departamento
# 14023  1250000.0         1186.0     320.0   7485.03  Departamento
# 15715  4500000.0         1100.0       0.0  15000.00  Departamento

# %%
valor = datos['Valor']

# %%
Q1 = valor.quantile(.25) #Cuartil 1, representa el 25%
Q3 = valor.quantile(.75) #Cuartil 3, representa el 75%
IIQ = Q3 - Q1 #Intevalo intercuartil
limite_inferior = Q1 - 1.5 * IIQ #Debajo de este valor es un outliers
limite_superior = Q3 + 1.5 * IIQ #Por arriba de este valor es un outliers

# %%
seleccion = (valor >= limite_inferior) & (valor <= limite_superior)

# %%
new_datos = datos[seleccion]

# %%
new_datos.boxplot(['Valor'])

# %%
#Histograma, sirve para mostrar la distribucion de frecuencia de los datos
datos.hist(['Valor'])
#No se puede tomar una conclusion sobre el dataframe original
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b60c1b760>]],
#       dtype=object)

# %%
new_datos.hist(['Valor'])
#Se puede observar que la mayoria de alquileres esta en el rango de 2000 y la minoria en el rango de 10000
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2b60c8d790>]],
#       dtype=object)

# %%
#El valor del local depende tambien del tipo, por lo que para que sea mas exacto el analisis se hace lo siguiente
datos.boxplot(['Valor'], by = ['Tipo'])
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
grupo_tipo = datos.groupby('Tipo')['Valor']

# %%
type(grupo_tipo)
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
grupo_tipo.groups
# Out:
# {'Casa': [1, 22, 54, 57, 97, 101, 146, 162, 182, 241, 253, 256, 267, 289, 313, 319, 338, 343, 361, 382, 389, 403, 428, 438, 479, 480, 486, 517, 548, 549, 574, 579, 580, 626, 630, 639, 644, 645, 670, 686, 710, 731, 734, 771, 782, 792, 869, 886, 953, 999, 1046, 1053, 1136, 1141, 1143, 1175, 1196, 1268, 1275, 1336, 1355, 1370, 1391, 1434, 1448, 1452, 1463, 1468, 1495, 1498, 1511, 1611, 1629, 1681, 1687, 1691, 1696, 1709, 1734, 1742, 1787, 1836, 1861, 1901, 1931, 1959, 1968, 1987, 2046, 2066, 2083, 2102, 2128, 2134, 2135, 2160, 2198, 2229, 2232, 2239, ...], 'Casa comercial': [58, 138, 195, 327, 454, 491, 565, 578, 627, 649, 768, 784, 828, 910, 912, 914, 975, 1061, 1206, 1317, 1401, 1423, 1457, 1521, 1536, 1790, 1976, 2194, 2522, 2549, 2569, 2618, 2626, 2669, 2696, 2832, 2904, 2979, 3135, 3146, 3159, 3249, 3324, 3376, 3378, 3389, 3398, 3613, 3881, 3934, 3994, 4038, 4049, 4510, 4594, 4791, 4818, 4875, 4953, 4980, 5010, 5069, 5092, 5124, 5272, 5326, 5330, 5331, 5399, 5429, 5554, 5673, 5748,
# ...

# %%
Q1 = grupo_tipo.quantile(.25) #Cuartil 1, representa el 25%
Q3 = grupo_tipo.quantile(.75) #Cuartil 3, representa el 75%
IIQ = Q3 - Q1 #Intevalo intercuartil
limite_inferior = Q1 - 1.5 * IIQ #Debajo de este valor es un outliers
limite_superior = Q3 + 1.5 * IIQ #Por arriba de este valor es un outliers

# %%
limite_inferior
# Out:
# Tipo
# Casa                 -11950.0
# Casa comercial       -12000.0
# Casa de villa          -825.0
# Casa en condominio   -12875.0
# Departamento          -3250.0
# Habitación                0.0
# Name: Valor, dtype: float64

# %%
limite_superior
# Out:
# Tipo
# Casa                  22850.0
# Casa comercial        36000.0
# Casa de villa          3375.0
# Casa en condominio    32125.0
# Departamento           9950.0
# Habitación             2400.0
# Name: Valor, dtype: float64

# %%
datos_new = pd.DataFrame()
for tipo in grupo_tipo.groups.keys():
  eh_tipo = datos['Tipo'] == tipo
  eh_dentro_limite = (datos['Valor'] >= limite_inferior[tipo]) & (datos['Valor'] <= limite_superior[tipo])
  seleccion = eh_tipo & eh_dentro_limite
  datos_seleccion = datos[seleccion]
  datos_new = pd.concat([datos_new, datos_seleccion])

# %%
datos_new.boxplot(['Valor'],by = ['Tipo'])
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
datos_new.to_csv('alquiler_residencial_sin_outliers.csv', sep = ';', index = False)

# %% [markdown]
# # Mas sobre graficos

# %%
plt.rc('figure', figsize = (15,10))

# %%
datos = pd.read_csv('alquiler_residencial_sin_outliers.csv', sep = ';')
datos.head(10)
# Out:
#    Tipo                Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0  Casa              Lurigancho        2         0       1   100   7000.0
# 1  Casa                   Lince        4         1       2   400  12000.0
# 2  Casa             Santa Anita        2         0       0    51   1500.0
# 3  Casa                San Luis        8         3       5   259   7000.0
# 4  Casa                   Breña        1         0       0    33   1200.0
# 5  Casa                   Lurín        3         2       1   135   3000.0
# 6  Casa               San Borja        2         0       0    40    950.0
# 7  Casa              San Miguel        4         1       1   191   4000.0
# 8  Casa                 Mi Perú        5         4       2   450   7000.0
# 9  Casa  San Juan de Miraflores        2         1       0    59   1200.0
#
#    Mantenimiento  Impuesto  Valor m2 Tipo Agrupado
# 0            0.0       0.0     70.00          Casa
# 1            0.0       0.0     30.00          Casa
# ...

# %%
area = plt.figure()

# %%
#Generar las dimensiones del grafico
g1 = area.add_subplot(2,2,1) #Grafico 1, 2 lineas, 2 columnas, primera posicion
g2 = area.add_subplot(2,2,2)
g3 = area.add_subplot(2,2,3)
g4 = area.add_subplot(2,2,4)

# %%
#Crear graficos
g1.scatter(datos.Valor, datos.Area) #Grafico de dispersion
g1.set_title('Valor x Area')

g2.hist(datos.Valor) #Histograma
g2.set_title('Histograma')

datos_g3 = datos.Valor.sample(100) #Muestra aleatoria de 100 registros de la columna Valor
datos_g3.index = range(datos_g3.shape[0]) #Corregir los indices
g3.plot(datos_g3) #Grafico de lineas
g3.set_title('Muestra (Valor)')

grupo = datos.groupby('Tipo')['Valor']
label = grupo.mean().index #Genero las etiquetas
valores = grupo.mean().values
g4.bar(label, valores)
g4.set_title('Valor Medio por Tipo')
# Out:
# Text(0.5, 1.0, 'Valor Medio por Tipo')

# %%
area

# %%
#Exportar grafico
area.savefig('grafico.png', dpi = 300, bbox = 'tight') #dpi: pixeles, bbox ='tight' (que los bordes sean ajustados)
